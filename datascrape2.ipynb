# %%
import numpy as np
import pandas as pd
import requests
import bs4
from bs4 import BeautifulSoup

# %%
# !python --version
# Out:
# Python 3.7.6

# %%
print("Numpy version: ", np.__version__)
print("Pandas version: ", pd.__version__)
print("Requests version: ", requests.__version__)
print("Beautiful Soup version: ", bs4.__version__)
# Out:
# Numpy version:  1.18.1
# Pandas version:  1.0.1
# Requests version:  2.22.0
# Beautiful Soup version:  4.8.2

# %%
session = requests.Session()
session.headers
# Out:
# {'User-Agent': 'python-requests/2.22.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
url = 'http://gamefaqs.gamespot.com/nes/563408-dragon-warrior/faqs/69121'

# %%
headers = {
    #'Access-Control-Allow-Origin': '*',
    #'Access-Control-Allow-Methods': 'GET',
    #'Access-Control-Allow-Headers': 'Content-Type',
    #'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'
    }

# %%
req = requests.get(url, headers=headers)
req.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(req.content, 'html.parser')
#print(soup.prettify())

# %%
monster_table = soup.find('table', class_='ffaq')

# %%
table_rows = monster_table.find_all('tr')

# %%
len(table_rows)
# Out:
# 42

# %%
row_headers = table_rows.pop(0)
table_rows.pop(20)
# Out:
# <tr><th class="ffaq">Name</th><th class="ffaq">STR</th><th class="ffaq">AGI</th><th class="ffaq">MAX.HP</th><th class="ffaq">EXP</th><th class="ffaq">Max.GOLD</th><th class="ffaq">Special 1</th><th class="ffaq">Prob.1</th><th class="ffaq">Special 2</th><th class="ffaq">Prob.2</th><th class="ffaq">Sleep Res.</th><th class="ffaq">Stopspell Res.</th><th class="ffaq">Hurt Res.</th><th class="ffaq">Evasion</th></tr>

# %%
len(table_rows)
# Out:
# 40

# %%
df_rows = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    df_rows.append(row)

df_rows[-1]
# Out:
# ['Dragonlord',
#  '140',
#  '200',
#  '130',
#  '0',
#  '0',
#  '',
#  '',
#  'Breathe fire 2',
#  '2/4',
#  '15/16',
#  '15/16',
#  '15/16',
#  '0/64']

# %%
col_names = [i.text for i in row_headers.find_all('th')]
col_names
# Out:
# ['Name',
#  'STR',
#  'AGI',
#  'MAX.HP',
#  'EXP',
#  'Max.GOLD',
#  'Special 1',
#  'Prob.1',
#  'Special 2',
#  'Prob.2',
#  'Sleep Res.',
#  'Stopspell Res.',
#  'Hurt Res.',
#  'Evasion']

# %%
df = pd.DataFrame(df_rows, columns=col_names)
df.head()
# Out:
#         Name STR AGI MAX.HP EXP Max.GOLD Special 1 Prob.1 Special 2 Prob.2  \
# 0      Slime   5   3      3   1        1
# 1  Red Slime   7   3      4   1        2
# 2     Drakee   9   6      6   2        2
# 3      Ghost  11   8      7   3        4
# 4   Magician  11  12     13   4       11                       Hurt    2/4
#
#   Sleep Res. Stopspell Res. Hurt Res. Evasion
# 0       0/16          15/16      0/16    1/64
# 1       0/16          15/16      0/16    1/64
# 2       0/16          15/16      0/16    1/64
# 3       0/16          15/16      0/16    4/64
# 4       0/16           0/16      0/16    1/64

# %%
# HP and GP range.split(' - ')
faq_lines = open('./data/game_data/monster_stats_faq.txt').readlines()

# %%
hp_lines = [line for line in faq_lines if 'HP:' in line]
gp_lines = [line for line in faq_lines if 'GP:' in line]

# %%
hp_min = [''.join(line.split())[3:].split('-')[0] for line in hp_lines]
gp_min = [''.join(line.split())[3:].split('-')[0] for line in gp_lines]

# %%
col_names.insert(3, 'min_hp')
col_names.insert(6, 'min_gold')

# %%
#df_rows.insert(3, hp_min)
#df_rows.insert(6, gp_min)

# %%
#df_rows
for idx, row in enumerate(df_rows):
    row.insert(3, hp_min[idx])

for idx, row in enumerate(df_rows):
    row.insert(6, gp_min[idx])

# %%
col_names = ['monster', 'str', 'agi', 'hp_min', 'hp_max', 'exp', 'gp_min', 'gp_max', 'sk1', 'p1', 's2', 'p2', 'res_sleep', 'res stopspell', 'res_hurt', 'evade']

# %%
df = pd.DataFrame(df_rows, columns=col_names)
df
# Out:
#            monster  str  agi hp_min hp_max  exp gp_min gp_max        sk1   p1  \
# 0            Slime    5    3      3      3    1      1      1
# 1        Red Slime    7    3      4      4    1      2      2
# 2           Drakee    9    6      5      6    2      2      2
# 3            Ghost   11    8      6      7    3      3      4
# 4         Magician   11   12     10     13    4      9     11
# 5       Magidrakee   14   14     12     15    5      9     11
# 6         Scorpion   18   16     16     20    6     12     15
# 7            Druin   20   18     17     22    7     12     15
# 8      Poltergeist   18   20     18     23    8     13     17
# 9            Droll   24   24     19     25   10     18     24
# 10        Drakeema   22   26     16     20   11     15     19       Heal  1/4
# 11        Skeleton   28   22     23     30   11     22     29
# 12         Warlock   28   22     23     30   13     26     34      Sleep  1/4
# 13  Metal Scorpion   36   42     17     22   14     30     39
# 14            Wolf   40   30     26     34   16     37     49
# 15          Wraith   44   34     28     36   17     45     59       Heal  1/4
# 16     Metal Slime   10  255      4      4  115      4      5
# 17         Specter   40   38     28     36   18     52     69      Sleep  1/4
# 18        Wolflord   50   36     29     38   20     60     79  Stopspell  2/4
# 19       Druinlord   47   40     27     35   20     63     84       Heal  3/4
# 20       Drollmagi   52   50     29     38   22     67     89  Stopspell  2/4
# 21          Wyvern   56   48     32     42   24     75     99
# 22  Rogue Scorpion   60   90     27     35   26     82    109
# 23   Wraith Knight   68   56     35     46   28     90    119       Heal  3/4
# 24           Golem  120   60     53     70    5      7      9
# 25         Goldman   48   40     38     50    6    150    199
# 26          Knight   76   78     42     55   33     97    129  Stopspell  2/4
# 27      Magiwyvern   78   68     44     58   34    105    139      Sleep  2/4
# 28    Demon Knight   79   64     38     50   37    112    149
# 29        Werewolf   86   70     46     60   40    116    154
# 30    Green Dragon   88   74     49     65   45    120    159
# 31      Starwyvern   86   80     49     65   43    120    159   Healmore  3/4
# 32          Wizard   80   70     49     65   50    123    164
# 33      Axe Knight   94   82     53     70   54    123    164      Sleep  1/4
# 34     Blue Dragon   98   84     53     70   60    112    149
# 35        Stoneman  100   40    121    160   65    105    139
# 36  Armored Knight  105   86     68     90   70    105    139   Healmore  3/4
# 37      Red Dragon  120   90     76    100  100    105    139      Sleep  1/4
# 38      Dragonlord   90   75     76    100    0      0      0  Stopspell  1/4
# 39      Dragonlord  140  200    130    130    0      0      0
#
#                 s2   p2 res_sleep res stopspell res_hurt  evade
# 0                            0/16         15/16     0/16   1/64
# 1                            0/16         15/16     0/16   1/64
# 2                            0/16         15/16     0/16   1/64
# 3                            0/16         15/16     0/16   4/64
# 4             Hurt  2/4      0/16          0/16     0/16   1/64
# 5             Hurt  2/4      0/16          0/16     0/16   1/64
# 6                            0/16         15/16     0/16   1/64
# 7                            0/16         15/16     0/16   2/64
# 8             Hurt  3/4      0/16          0/16     0/16   6/64
# 9                            0/16         14/16     0/16   2/64
# 10            Hurt  2/4      2/16          0/16     0/16   6/64
# 11                           0/16         15/16     0/16   4/64
# 12            Hurt  2/4      3/16          1/16     0/16   2/64
# 13                           0/16         15/16     0/16   2/64
# 14                           1/16         15/16     0/16   2/64
# 15                           7/16          0/16     0/16   4/64
# 16            Hurt  3/4     15/16         15/16    15/16   1/64
# 17            Hurt  3/4      3/16          1/16     0/16   4/64
# 18                           4/16          7/16     0/16   2/64
# 19            Hurt  1/4     15/16          0/16     0/16   4/64
# 20                           2/16          2/16     0/16   1/64
# 21                           4/16         15/16     0/16   2/64
# 22                           7/16         15/16     0/16   2/64
# 23                           5/16          0/16     3/16   4/64
# 24                          15/16         15/16    15/16   0/64
# 25                          13/16         15/16     0/16   1/64
# 26                           6/16          7/16     0/16   1/64
# 27                           2/16          0/16     0/16   2/64
# 28                          15/16         15/16    15/16  15/64
# 29                           7/16         15/16     0/16   7/64
# 30    Breathe fire  1/4      7/16         15/16     2/16   2/64
# 31    Breathe fire  1/4      8/16          0/16     1/16   2/64
# 32            Hurt  2/4     15/16          7/16    15/16   2/64
# 33                          15/16          3/16     1/16   1/64
# 34    Breathe fire  1/4     15/16         15/16     7/16   2/64
# 35                           2/16         15/16     7/16   1/64
# 36        Hurtmore  1/4     15/16          7/16     1/16   2/64
# 37    Breathe fire  1/4     15/16          7/16    15/16   2/64
# 38        Hurtmore  3/4     15/16         15/16    15/16   0/64
# 39  Breathe fire 2  2/4     15/16         15/16    15/16   0/64
